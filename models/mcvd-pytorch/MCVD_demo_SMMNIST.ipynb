# %%
# %load_ext autoreload
# %autoreload 2
import sys, os

# %%
import glob, os
import mediapy as media
import torch
from torch.utils.data import DataLoader

from load_model_from_ckpt import load_model, get_sampler, init_samples
from datasets import get_dataset, data_transform, inverse_data_transform
from runners.ncsn_runner import conditioning_fn

from os.path import expanduser
home = expanduser("~")

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import glob, os
# ----> 2 import mediapy as media
#       3 import torch
#       4 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'mediapy'

# %% [markdown]
# # Set directories to download model, data

# %%
# SET THESE!!!https://drive.google.com/drive/folders/18SylLyGf47VinnI4aPiWfOn9Cnt3NgG2
GDRIVE_URL = "https://drive.google.com/drive/folders/1bM6wqU_kymoljz5uYQRCYNup_8adBfLH" # smmnist_big_5c5_unetm_b2
EXP_PATH = os.path.join(home, "scratch/MCVD_SMMNIST_pred")
DATA_PATH = os.path.join(home, "scratch/Datasets/MNIST")

# %% [markdown]
# # Download experiment (model checkpoint, config, etc.)

# %%
# !gdown --fuzzy {GDRIVE_URL} -O {EXP_PATH}/ --folder
# Out:
# Retrieving folder list
# Retrieving folder 1CzwozDKbsOH_V2099N9-HBeeMO4441iT logs
# Processing file 14Di0OplaG_F-Ogmmv8w_K0NqYP5Bag9r args.yml
# Processing file 1uTfMtTfTT5WMAdDR1x2WNrOQnldk__yA checkpoint_140000.pt
# Processing file 1xOY4-oh7jSCSKqtDktvtTCt3CasNzT64 config.yml
# Processing file 1zuqnoOOxfvBzjpgaFR77j8OGUUs808oj epochs.png
# Processing file 1PMXh9CluffmccQO_llGmRMf6DRhXU9Db fvd_log.png
# Processing file 1BWgT0O20aaa-TtsKezIB1UxMzNkL0HOH fvd.png
# Processing file 1DWk2o8zyj4h9lfaZcLbUxln4ZiV7z04v grad_log.png
# Processing file 10iH96rRLPlHPRaZHuS7SNdYg0KjOlah6 grad.png
# Processing file 1Eebka2ybBXoYXBGOdom1059LEl2wyC-f loss_log.png
# Processing file 1SmtLNaMHHUV4L6SXGV_QacQ7augGQBC3 loss.png
# Processing file 1hQo6pWh3pIHteyVx90_YzsDg9Z-BKSHm lpips_log.png
# Processing file 1I2sme46c9twlixOYkThZxcIh8ptpzBZz lpips.png
# Processing file 1B_LvuvnNmmNKqacX2NLx4_-_0o6dniuZ lr.png
# Processing file 1v6i8iwed7QDw84LKpsl9jpoAQZ-UZ410 meters.pkl
# Processing file 1cmaGJZ3El7xe91JvJkt4QpA00HYwnATA mse_log.png
# Processing file 1Pgl_r02PK_FF16dmWIe9yTy-86Y8qr3K mse.png
# Processing file 1WzFIEP5HjdtWzeiqSdYZgXDmDlOTqY-q psnr_log.png
# Processing file 1FTRbdRjNWjgzhPgo830ryRoQbtHK4MIB psnr.png
# Processing file 1zhhX8DbMWO2I_SQgHSY1owV6YGKYh63F ssim_log.png
# Processing file 1cFGvi1IlVp6LuhBs8tWWLxiggAmBGIT8 ssim.png
# Processing file 1JSzpI1ulL7rr2ViPoaT9vnIvOliXTz_J stdout.txt
# Processing file 1Wb9uHqMN3ZsayV5K9XvKtMlKwYkYKfg6 time_elapsed.png
# Processing file 11LJ_8ikBK891lGoXylixieqbOeDiLqlJ time_train.png
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=14Di0OplaG_F-Ogmmv8w_K0NqYP5Bag9r
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/args.yml
# 100%|██████████████████████████████████████| 1.09k/1.09k [00:00<00:00, 3.12MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uTfMtTfTT5WMAdDR1x2WNrOQnldk__yA
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/checkpoint_140000.pt
# 100%|████████████████████████████████████████| 864M/864M [00:21<00:00, 40.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xOY4-oh7jSCSKqtDktvtTCt3CasNzT64
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/config.yml
# 100%|██████████████████████████████████████| 1.90k/1.90k [00:00<00:00, 6.71MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zuqnoOOxfvBzjpgaFR77j8OGUUs808oj
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/epochs.png
# 100%|██████████████████████████████████████| 20.6k/20.6k [00:00<00:00, 15.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1PMXh9CluffmccQO_llGmRMf6DRhXU9Db
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/fvd_log.png
# 100%|██████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 2.89MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BWgT0O20aaa-TtsKezIB1UxMzNkL0HOH
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/fvd.png
# 100%|██████████████████████████████████████| 24.2k/24.2k [00:00<00:00, 6.85MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1DWk2o8zyj4h9lfaZcLbUxln4ZiV7z04v
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/grad_log.png
# 100%|██████████████████████████████████████| 32.3k/32.3k [00:00<00:00, 66.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10iH96rRLPlHPRaZHuS7SNdYg0KjOlah6
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/grad.png
# 100%|██████████████████████████████████████| 20.4k/20.4k [00:00<00:00, 8.96MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Eebka2ybBXoYXBGOdom1059LEl2wyC-f
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/loss_log.png
# 100%|██████████████████████████████████████| 42.8k/42.8k [00:00<00:00, 44.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SmtLNaMHHUV4L6SXGV_QacQ7augGQBC3
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/loss.png
# 100%|██████████████████████████████████████| 21.0k/21.0k [00:00<00:00, 21.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hQo6pWh3pIHteyVx90_YzsDg9Z-BKSHm
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/lpips_log.png
# 100%|██████████████████████████████████████| 28.6k/28.6k [00:00<00:00, 2.70MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1I2sme46c9twlixOYkThZxcIh8ptpzBZz
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/lpips.png
# 100%|██████████████████████████████████████| 24.0k/24.0k [00:00<00:00, 26.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1B_LvuvnNmmNKqacX2NLx4_-_0o6dniuZ
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/lr.png
# 100%|██████████████████████████████████████| 22.2k/22.2k [00:00<00:00, 11.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1v6i8iwed7QDw84LKpsl9jpoAQZ-UZ410
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/meters.pkl
# 100%|██████████████████████████████████████| 18.1M/18.1M [00:00<00:00, 60.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cmaGJZ3El7xe91JvJkt4QpA00HYwnATA
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/mse_log.png
# 100%|██████████████████████████████████████| 26.1k/26.1k [00:00<00:00, 2.47MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Pgl_r02PK_FF16dmWIe9yTy-86Y8qr3K
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/mse.png
# 100%|██████████████████████████████████████| 23.8k/23.8k [00:00<00:00, 30.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WzFIEP5HjdtWzeiqSdYZgXDmDlOTqY-q
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/psnr_log.png
# 100%|██████████████████████████████████████| 25.6k/25.6k [00:00<00:00, 20.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FTRbdRjNWjgzhPgo830ryRoQbtHK4MIB
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/psnr.png
# 100%|██████████████████████████████████████| 23.6k/23.6k [00:00<00:00, 2.34MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zhhX8DbMWO2I_SQgHSY1owV6YGKYh63F
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/ssim_log.png
# 100%|██████████████████████████████████████| 27.0k/27.0k [00:00<00:00, 2.60MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cFGvi1IlVp6LuhBs8tWWLxiggAmBGIT8
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/ssim.png
# 100%|██████████████████████████████████████| 23.9k/23.9k [00:00<00:00, 24.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JSzpI1ulL7rr2ViPoaT9vnIvOliXTz_J
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/stdout.txt
# 100%|██████████████████████████████████████| 1.66M/1.66M [00:00<00:00, 14.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Wb9uHqMN3ZsayV5K9XvKtMlKwYkYKfg6
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/time_elapsed.png
# 100%|██████████████████████████████████████| 19.4k/19.4k [00:00<00:00, 16.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11LJ_8ikBK891lGoXylixieqbOeDiLqlJ
# To: /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/time_train.png
# 100%|██████████████████████████████████████| 18.4k/18.4k [00:00<00:00, 25.1MB/s]
# Download completed

# %% [markdown]
# # Load model checkpoint

# %%
EXP_PATH = "/home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs"
ckpt_path = glob.glob(os.path.join(EXP_PATH, "checkpoint_*.pt"))[0]
scorenet, config = load_model(ckpt_path, device)
sampler = get_sampler(config)

# %%
print(device)
print(ckpt_path)
print(config)
# Out:
# cuda
# /home/thekej/scratch/MCVD_SMMNIST_pred/smmnist_big_c5t5_SPADE/logs/checkpoint_140000.pt
# Namespace(data=Namespace(channels=1, dataset='StochasticMovingMNIST', gaussian_dequantization=False, image_size=64, logit_transform=False, num_digits=2, num_frames=5, num_frames_cond=5, num_workers=0, prob_mask_cond=0.0, random_flip=True, rescaled=True, step_length=0.1, uniform_dequantization=False), device=device(type='cuda'), fast_fid=Namespace(batch_size=1000, begin_ckpt=5000, end_ckpt=300000, ensemble=False, freq=5000, n_steps_each=0, num_samples=1000, pr_nn_k=3, step_lr=0.0, verbose=False), model=Namespace(arch='unetmore', attn_resolutions=[8, 16, 32], ch_mult=[1, 2, 3, 4], cond_emb=False, conditional=True, depth='deep', dropout=0.1, ema=True, ema_rate=0.999, gamma=False, gff=False, n_head_channels=64, ngf=64, noise_in_cond=False, nonlinearity='swish', normalization='InstanceNorm++', num_classes=1000, num_res_blocks=2, output_all_frames=False, sigma_begin=0.02, sigma_dist='linear', sigma_end=0.0001, spade=True, spec_norm=False, time_conditional=True, type='v1', version='DDPM'), optim=Namespace(amsgrad=False, beta1=0.9, eps=1e-08, grad_clip=1.0, lr=0.0002, optimizer='Adam', warmup=1000, weight_decay=0.0), sampling=Namespace(batch_size=100, ckpt_id=0, clip_before=True, consistent=True, data_init=False, denoise=True, fid=False, final_only=True, fvd=True, init_prev_t=-1.0, inpainting=False, interpolation=False, max_data_iter=100000, n_interpolations=15, n_steps_each=0, num_frames_pred=20, num_samples4fid=10000, num_samples4fvd=10000, one_frame_at_a_time=False, preds_per_test=1, ssim=True, step_lr=0.0, subsample=100, train=False), test=Namespace(batch_size=100, begin_ckpt=5000, end_ckpt=300000), training=Namespace(L1=False, batch_size=64, log_all_sigmas=False, log_freq=50, n_epochs=1000000, n_iters=3000001, sample_freq=50000, snapshot_freq=50000, snapshot_sampling=True, val_freq=100))

# %% [markdown]
# # Load data

# %%
dataset, test_dataset = get_dataset(DATA_PATH, config, video_frames_pred=config.data.num_frames)
# Out:
# Dataset length: 60000
# Dataset length: 256

# %%
# dataloader = DataLoader(dataset, batch_size=config.training.batch_size, shuffle=True,
#                         num_workers=config.data.num_workers)
# train_iter = iter(dataloader)
# x, y = next(train_iter)

test_loader = DataLoader(test_dataset, batch_size=config.training.batch_size, shuffle=False,
                         num_workers=config.data.num_workers, drop_last=True)
test_iter = iter(test_loader)
test_x, test_y = next(test_iter)
print(test_x.shape)
# Out:
# torch.Size([64, 10, 1, 64, 64])

# %%
test_x = data_transform(config, test_x)
real, cond, cond_mask = conditioning_fn(config, test_x, num_frames_pred=config.data.num_frames,
                                        prob_mask_cond=getattr(config.data, 'prob_mask_cond', 0.0),
                                        prob_mask_future=getattr(config.data, 'prob_mask_future', 0.0))
print(real.shape, cond.shape)
# Out:
# torch.Size([64, 5, 64, 64]) torch.Size([64, 5, 64, 64])

# %%
i = 1
# media.show_images(torch.cat([cond[i].permute(0, 2, 3, 1), real[i].permute(0, 2, 3, 1)]))
media.show_images(torch.cat([cond[i], real[i]]))
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # Load initial samples

# %%
init = init_samples(len(real), config)

# %%
print(init.shape)
media.show_images(init[i])
# Out:
# torch.Size([64, 5, 64, 64])
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # Predict

# %%
pred = sampler(init, scorenet, cond=cond, cond_mask=cond_mask, subsample=100, verbose=True)
# Out:
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# spade
# out:  torch.Size([8, 64, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# spade
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# spade
# normalized:  torch.Size([8, 64, 64, 64])
# segmap:  torch.Size([8, 5, 64, 64])
# out:  torch.Size([8, 64, 64, 64])
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pred = sampler(init, scorenet, cond=cond, cond_mask=cond_mask, subsample=100, verbose=True)
#
# File ~/models/mcvd-pytorch/load_model_from_ckpt.py:92, in get_sampler.<locals>.sampler_fn(init, scorenet, cond, cond_mask, subsample, verbose)
#      90 if cond_mask is not None:
#      91     cond_mask = cond_mask.to(config.device)
# ---> 92 return inverse_data_transform(config, sampler_partial(init, scorenet, cond=cond, cond_mask=cond_mask,
#      93                                                       subsample_steps=subsample, verbose=verbose)[-1].to('cpu'))
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/models/mcvd-pytorch/models/__init__.py:284, in ddpm_sampler(x_mod, scorenet, cond, just_beta, final_only, denoise, subsample_steps, same_noise, noise_val, frac_steps, verbose, log, clip_before, t_min, gamma, **kwargs)
#     282 c_beta, c_alpha, c_alpha_prev = betas[i], alphas[i], alphas_prev[i]
#     283 labels = (step * torch.ones(x_mod.shape[0], device=x_mod.device)).long()
# --> 284 grad, _, _ = scorenet(x_mod, labels)
#     286 # x_mod = 1 / (1 - c_beta).sqrt() * (x_mod + c_beta / (1 - c_alpha).sqrt() * grad)
#     287 x0 = (1 / c_alpha.sqrt()) * (x_mod - (1 - c_alpha).sqrt() * grad)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:168, in DataParallel.forward(self, *inputs, **kwargs)
#     166     return self.module(*inputs[0], **kwargs[0])
#     167 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 168 outputs = self.parallel_apply(replicas, inputs, kwargs)
#     169 return self.gather(outputs, self.output_device)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:178, in DataParallel.parallel_apply(self, replicas, inputs, kwargs)
#     177 def parallel_apply(self, replicas, inputs, kwargs):
# --> 178     return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/parallel/parallel_apply.py:86, in parallel_apply(modules, inputs, kwargs_tup, devices)
#      84     output = results[i]
#      85     if isinstance(output, ExceptionWrapper):
# ---> 86         output.reraise()
#      87     outputs.append(output)
#      88 return outputs
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/_utils.py:461, in ExceptionWrapper.reraise(self)
#     457 except TypeError:
#     458     # If the exception takes multiple arguments, don't try to
#     459     # instantiate since we don't know how to
#     460     raise RuntimeError(msg) from None
# --> 461 raise exception
#
# ImportError: Caught ImportError in replica 0 on device 0.
# Original Traceback (most recent call last):
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/nn/parallel/parallel_apply.py", line 61, in _worker
#     output = module(*input, **kwargs)
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/thekej/models/mcvd-pytorch/models/better/ncsnpp_more.py", line 772, in forward
#     return self.unet(x, y, cond, cond_mask=cond_mask)
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/thekej/models/mcvd-pytorch/models/better/ncsnpp_more.py", line 656, in forward
#     h = modules[m_idx](hs[-1], temb, cond=cond)
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/thekej/models/mcvd-pytorch/models/better/layerspp.py", line 698, in forward
#     h = up_or_down_sampling.downsample_2d(h, self.fir_kernel, factor=2)
#   File "/home/thekej/models/mcvd-pytorch/models/better/up_or_down_sampling.py", line 257, in downsample_2d
#     return upfirdn2d(x, torch.tensor(k, device=x.device),
#   File "/home/thekej/models/mcvd-pytorch/models/better/op/upfirdn2d.py", line 21, in upfirdn2d
#     upfirdn2d_op = load(
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/utils/cpp_extension.py", line 1202, in load
#     return _jit_compile(
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/utils/cpp_extension.py", line 1450, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#   File "/home/thekej/miniconda3/lib/python3.8/site-packages/torch/utils/cpp_extension.py", line 1844, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#   File "<frozen importlib._bootstrap>", line 556, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1166, in create_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ImportError: /home/thekej/.cache/torch_extensions/py38_cu113/upfirdn2d/upfirdn2d.so: cannot open shared object file: No such file or directory

# %%
print(pred.shape)
i = 1
media.show_images(torch.cat([cond[i], real[i]]))
media.show_images(torch.cat([cond[i], pred[i]]))
# Out:
# torch.Size([64, 5, 64, 64])
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
i = 4
media.show_images(torch.cat([cond[i], real[i]]))
media.show_images(torch.cat([cond[i], pred[i]]))
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="64" height="64" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
